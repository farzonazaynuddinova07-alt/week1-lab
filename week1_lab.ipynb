# %% [markdown]
# <a href="https://colab.research.google.com/github/farzonazaynuddinova07-alt/week1-lab/blob/main/week1_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Farzona Zayniddinova"

# %%
my_enrollment_number = "A85204925048"

# %%
my_hobby = "Travelling"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Farzona Zayniddinova, and my my enrollment number is A85204925048. I like Travelling.
